# %%
import torch
import numpy as np
from torch.utils import data
from torch.nn import init
from matplotlib import pyplot as plt
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# %%
#加载数据集
mnist_train = torchvision.datasets.FashionMNIST(root='~/Datasets/FashionMNIST', train=True,
download=True, transform=transforms.ToTensor())
mnist_test = torchvision.datasets.FashionMNIST(root='~/Datasets/FashionMNIST', train=False,
download=True, transform=transforms.ToTensor())

#定义模型参数
num_inputs, num_outputs, num_hiddens = 784, 10, 256

#定义计算测试集损失函数
def evaluate_loss(data_iter, net):
    l, n = 0.0, 0
    for X, y in data_iter:
        X = X.view((-1, num_inputs)) 
        l += loss(net(X),y).sum().item()
        n += y.shape[0]
    return l / n

#定义计算测试集准确率函数
def evaluate_accuracy(data_iter, net):
    acc_sum, n = 0.0, 0
    for X, y in data_iter:
        X = X.view((-1, num_inputs)) 
        acc_sum += (net(X).argmax(dim=1) == y).float().sum().item()
        n += y.shape[0]
    return acc_sum / n

#定义训练参数
batch_size, num_epochs, lr = 256, 30, 0.01

#划分数据集
train_iter = torch.utils.data.DataLoader(mnist_train, batch_size=batch_size, shuffle=True,num_workers=0)
test_iter = torch.utils.data.DataLoader(mnist_test, batch_size=batch_size, shuffle=False,num_workers=0)

# %%
# ========== Relu激活函数 ==========

class Relu_Classification(torch.nn.Module):
    def __init__(self):
        super(Relu_Classification, self).__init__()
        self.hidden = torch.nn.Linear(num_inputs, num_hiddens) #定义隐藏层函数
        self.relu = torch.nn.ReLU()                       #定义隐藏层激活函数
        self.output = torch.nn.Linear(num_hiddens, num_outputs)#定义输出层函数

    def forward(self, x):
        x = self.hidden(x)
        x = self.relu(x)
        x = self.output(x)
        return x
        
net = Relu_Classification()

#初始化模型参数
init.normal_(net.hidden.weight, mean=0, std=0.01)
init.normal_(net.output.weight, mean=0, std=0.01)
init.constant_(net.hidden.bias, val=0)
init.constant_(net.output.bias, val=0)

#定义损失函数和优化器
loss = torch.nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr)

#训练模型
loss_train_relu = []
loss_test_relu = []
acc_train_relu = []
acc_test_relu = []
for epoch in range(num_epochs):
    train_l_sum, train_acc_sum, n = 0.0, 0.0, 0
    for X, y in train_iter:
        X = X.view((-1, num_inputs)) 
        y_hat = net(X)
        l = loss(y_hat,y).sum()   
        optimizer.zero_grad()
        l.backward()       #计算损失     
        optimizer.step()   #更新梯度
        train_l_sum += l.item()
        train_acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
        n += y.shape[0]
    loss_train_relu.append(train_l_sum/n)
    loss_test_relu.append(evaluate_loss(test_iter,net))
    acc_train_relu.append(train_acc_sum/n)
    acc_test_relu.append(evaluate_accuracy(test_iter,net))
    print('epoch %d, loss_train %f, loss_test %f, acc_train %f, acc_test %f '% 
          (epoch+1, loss_train_relu[epoch], loss_test_relu[epoch], acc_train_relu[epoch], acc_test_relu[epoch]))
# Out:
# epoch 1, loss_train 0.008412, loss_test 0.007443, acc_train 0.369300, acc_test 0.492800
# epoch 2, loss_train 0.005934, loss_test 0.005049, acc_train 0.571683, acc_test 0.605900
# epoch 3, loss_train 0.004351, loss_test 0.004033, acc_train 0.643317, acc_test 0.651300
# epoch 4, loss_train 0.003643, loss_test 0.003543, acc_train 0.671433, acc_test 0.664100
# epoch 5, loss_train 0.003274, loss_test 0.003258, acc_train 0.689983, acc_test 0.688600
# epoch 6, loss_train 0.003043, loss_test 0.003060, acc_train 0.713050, acc_test 0.710600
# epoch 7, loss_train 0.002874, loss_test 0.002914, acc_train 0.735250, acc_test 0.732000
# epoch 8, loss_train 0.002737, loss_test 0.002788, acc_train 0.752667, acc_test 0.752300
# epoch 9, loss_train 0.002623, loss_test 0.002676, acc_train 0.765917, acc_test 0.763800
# epoch 10, loss_train 0.002523, loss_test 0.002591, acc_train 0.777867, acc_test 0.772500
# epoch 11, loss_train 0.002437, loss_test 0.002511, acc_train 0.787533, acc_test 0.780800
# epoch 12, loss_train 0.002362, loss_test 0.002439, acc_train 0.795017, acc_test 0.784600
# epoch 13, loss_train 0.002297, loss_test 0.002389, acc_train 0.800983, acc_test 0.788800
# epoch 14, loss_train 0.002242, loss_test 0.002347, acc_train 0.805933, acc_test 0.794000
# epoch 15, loss_train 0.002192, loss_test 0.002288, acc_train 0.811167, acc_test 0.799800
# epoch 16, loss_train 0.002149, loss_test 0.002248, acc_train 0.814517, acc_test 0.803000
# epoch 17, loss_train 0.002110, loss_test 0.002220, acc_train 0.817517, acc_test 0.805300
# epoch 18, loss_train 0.002075, loss_test 0.002189, acc_train 0.820283, acc_test 0.806900
# epoch 19, loss_train 0.002046, loss_test 0.002160, acc_train 0.822767, acc_test 0.810700
# epoch 20, loss_train 0.002016, loss_test 0.002138, acc_train 0.825650, acc_test 0.811700
# epoch 21, loss_train 0.001992, loss_test 0.002122, acc_train 0.826150, acc_test 0.813700
# epoch 22, loss_train 0.001969, loss_test 0.002089, acc_train 0.829433, acc_test 0.817400
# epoch 23, loss_train 0.001950, loss_test 0.002075, acc_train 0.830050, acc_test 0.817300
# epoch 24, loss_train 0.001930, loss_test 0.002060, acc_train 0.831333, acc_test 0.817900
# epoch 25, loss_train 0.001910, loss_test 0.002035, acc_train 0.832317, acc_test 0.820300
# epoch 26, loss_train 0.001895, loss_test 0.002025, acc_train 0.835000, acc_test 0.820800
# epoch 27, loss_train 0.001881, loss_test 0.002028, acc_train 0.835617, acc_test 0.821100
# epoch 28, loss_train 0.001866, loss_test 0.002023, acc_train 0.836633, acc_test 0.818300
# epoch 29, loss_train 0.001849, loss_test 0.001997, acc_train 0.837533, acc_test 0.823700
# epoch 30, loss_train 0.001839, loss_test 0.001989, acc_train 0.837867, acc_test 0.823600

# %%
# ========== LeakyReLU激活函数 ==========

class LeakyReLU_Classification(torch.nn.Module):
    def __init__(self):
        super(LeakyReLU_Classification, self).__init__()
        self.hidden = torch.nn.Linear(num_inputs, num_hiddens) #定义隐藏层函数
        self.leakyrelu = torch.nn.LeakyReLU()                     #定义隐藏层激活函数
        self.output = torch.nn.Linear(num_hiddens, num_outputs)#定义输出层函数

    def forward(self, x):
        x = self.hidden(x)
        x = self.leakyrelu(x)
        x = self.output(x)
        return x
        
net = LeakyReLU_Classification()

#初始化模型参数
init.normal_(net.hidden.weight, mean=0, std=0.01)
init.normal_(net.output.weight, mean=0, std=0.01)
init.constant_(net.hidden.bias, val=0)
init.constant_(net.output.bias, val=0)

#定义损失函数和优化器
loss = torch.nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr)

#训练模型
loss_train_leakyrelu = []
loss_test_leakyrelu = []
acc_train_leakyrelu = []
acc_test_leakyrelu = []
for epoch in range(num_epochs):
    train_l_sum, train_acc_sum, n = 0.0, 0.0, 0
    for X, y in train_iter:
        X = X.view((-1, num_inputs)) 
        y_hat = net(X)
        l = loss(y_hat,y).sum()  
        optimizer.zero_grad()
        l.backward()       #计算损失     
        optimizer.step()   #更新梯度
        train_l_sum += l.item()
        train_acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
        n += y.shape[0]
    loss_train_leakyrelu.append(train_l_sum/n)
    loss_test_leakyrelu.append(evaluate_loss(test_iter,net))
    acc_train_leakyrelu.append(train_acc_sum/n)
    acc_test_leakyrelu.append(evaluate_accuracy(test_iter,net))
    print('epoch %d, loss_train %f, loss_test %f, acc_train %f, acc_test %f '% 
          (epoch+1, loss_train_leakyrelu[epoch], loss_test_leakyrelu[epoch], acc_train_leakyrelu[epoch], acc_test_leakyrelu[epoch]))
# Out:
# epoch 1, loss_train 0.008451, loss_test 0.007518, acc_train 0.395400, acc_test 0.551100
# epoch 2, loss_train 0.005977, loss_test 0.005056, acc_train 0.590483, acc_test 0.628800
# epoch 3, loss_train 0.004348, loss_test 0.004019, acc_train 0.649233, acc_test 0.651700
# epoch 4, loss_train 0.003633, loss_test 0.003526, acc_train 0.673967, acc_test 0.672700
# epoch 5, loss_train 0.003261, loss_test 0.003245, acc_train 0.695767, acc_test 0.698500
# epoch 6, loss_train 0.003031, loss_test 0.003050, acc_train 0.719967, acc_test 0.716300
# epoch 7, loss_train 0.002860, loss_test 0.002901, acc_train 0.740217, acc_test 0.734300
# epoch 8, loss_train 0.002726, loss_test 0.002769, acc_train 0.755917, acc_test 0.753100
# epoch 9, loss_train 0.002612, loss_test 0.002666, acc_train 0.769417, acc_test 0.767200
# epoch 10, loss_train 0.002512, loss_test 0.002574, acc_train 0.780083, acc_test 0.773700
# epoch 11, loss_train 0.002429, loss_test 0.002500, acc_train 0.788750, acc_test 0.779600
# epoch 12, loss_train 0.002357, loss_test 0.002440, acc_train 0.796533, acc_test 0.783600
# epoch 13, loss_train 0.002292, loss_test 0.002377, acc_train 0.802167, acc_test 0.791000
# epoch 14, loss_train 0.002238, loss_test 0.002327, acc_train 0.807367, acc_test 0.796800
# epoch 15, loss_train 0.002190, loss_test 0.002286, acc_train 0.811750, acc_test 0.797900
# epoch 16, loss_train 0.002147, loss_test 0.002246, acc_train 0.814717, acc_test 0.802200
# epoch 17, loss_train 0.002107, loss_test 0.002212, acc_train 0.818233, acc_test 0.805600
# epoch 18, loss_train 0.002074, loss_test 0.002182, acc_train 0.821433, acc_test 0.808300
# epoch 19, loss_train 0.002042, loss_test 0.002154, acc_train 0.823700, acc_test 0.810200
# epoch 20, loss_train 0.002017, loss_test 0.002129, acc_train 0.825450, acc_test 0.812700
# epoch 21, loss_train 0.001994, loss_test 0.002111, acc_train 0.827383, acc_test 0.813100
# epoch 22, loss_train 0.001970, loss_test 0.002097, acc_train 0.828867, acc_test 0.816500
# epoch 23, loss_train 0.001947, loss_test 0.002074, acc_train 0.830450, acc_test 0.817600
# epoch 24, loss_train 0.001927, loss_test 0.002056, acc_train 0.831950, acc_test 0.817000
# epoch 25, loss_train 0.001911, loss_test 0.002036, acc_train 0.833533, acc_test 0.822800
# epoch 26, loss_train 0.001894, loss_test 0.002027, acc_train 0.834483, acc_test 0.821300
# epoch 27, loss_train 0.001879, loss_test 0.002005, acc_train 0.836700, acc_test 0.821900
# epoch 28, loss_train 0.001862, loss_test 0.002026, acc_train 0.837600, acc_test 0.820500
# epoch 29, loss_train 0.001849, loss_test 0.001979, acc_train 0.837983, acc_test 0.825100
# epoch 30, loss_train 0.001836, loss_test 0.001970, acc_train 0.839983, acc_test 0.825800

# %%
# ========== Tanh激活函数 ==========

class Tanh_Classification(torch.nn.Module):
    def __init__(self):
        super(Tanh_Classification, self).__init__()
        self.hidden = torch.nn.Linear(num_inputs, num_hiddens) #定义隐藏层函数
        self.tanh = torch.nn.Tanh()                            #定义隐藏层激活函数
        self.output = torch.nn.Linear(num_hiddens, num_outputs)#定义输出层函数

    def forward(self, x):
        x = self.hidden(x)
        x = self.tanh(x)
        x = self.output(x)
        return x
        
net = Tanh_Classification()

#初始化模型参数
init.normal_(net.hidden.weight, mean=0, std=0.01)
init.normal_(net.output.weight, mean=0, std=0.01)
init.constant_(net.hidden.bias, val=0)
init.constant_(net.output.bias, val=0)

#定义损失函数和优化器
loss = torch.nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr)

#训练模型
loss_train_tanh = []
loss_test_tanh = []
acc_train_tanh = []
acc_test_tanh = []
for epoch in range(num_epochs):
    train_l_sum, train_acc_sum, n = 0.0, 0.0, 0
    for X, y in train_iter:
        X = X.view((-1, num_inputs)) 
        y_hat = net(X)
        l = loss(y_hat,y).sum()  
        optimizer.zero_grad()
        l.backward()       #计算损失     
        optimizer.step()   #更新梯度
        train_l_sum += l.item()
        train_acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
        n += y.shape[0]
    loss_train_tanh.append(train_l_sum/n)
    loss_test_tanh.append(evaluate_loss(test_iter,net))
    acc_train_tanh.append(train_acc_sum/n)
    acc_test_tanh.append(evaluate_accuracy(test_iter,net))
    print('epoch %d, loss_train %f, loss_test %f, acc_train %f, acc_test %f '% 
          (epoch+1, loss_train_tanh[epoch], loss_test_tanh[epoch], acc_train_tanh[epoch], acc_test_tanh[epoch]))
# Out:
# epoch 1, loss_train 0.008068, loss_test 0.006766, acc_train 0.469750, acc_test 0.558400
# epoch 2, loss_train 0.005493, loss_test 0.004812, acc_train 0.590700, acc_test 0.622100
# epoch 3, loss_train 0.004224, loss_test 0.003972, acc_train 0.648100, acc_test 0.655500
# epoch 4, loss_train 0.003605, loss_test 0.003514, acc_train 0.679950, acc_test 0.675800
# epoch 5, loss_train 0.003246, loss_test 0.003226, acc_train 0.704850, acc_test 0.699500
# epoch 6, loss_train 0.003009, loss_test 0.003025, acc_train 0.728250, acc_test 0.722300
# epoch 7, loss_train 0.002834, loss_test 0.002866, acc_train 0.745283, acc_test 0.740800
# epoch 8, loss_train 0.002695, loss_test 0.002741, acc_train 0.759000, acc_test 0.753400
# epoch 9, loss_train 0.002580, loss_test 0.002637, acc_train 0.769933, acc_test 0.761800
# epoch 10, loss_train 0.002484, loss_test 0.002549, acc_train 0.780117, acc_test 0.774500
# epoch 11, loss_train 0.002401, loss_test 0.002475, acc_train 0.788917, acc_test 0.782100
# epoch 12, loss_train 0.002331, loss_test 0.002413, acc_train 0.795933, acc_test 0.787100
# epoch 13, loss_train 0.002266, loss_test 0.002352, acc_train 0.801367, acc_test 0.792000
# epoch 14, loss_train 0.002214, loss_test 0.002304, acc_train 0.806250, acc_test 0.797100
# epoch 15, loss_train 0.002165, loss_test 0.002259, acc_train 0.810867, acc_test 0.800000
# epoch 16, loss_train 0.002121, loss_test 0.002220, acc_train 0.814267, acc_test 0.802200
# epoch 17, loss_train 0.002083, loss_test 0.002184, acc_train 0.817917, acc_test 0.805800
# epoch 18, loss_train 0.002048, loss_test 0.002154, acc_train 0.820117, acc_test 0.810400
# epoch 19, loss_train 0.002017, loss_test 0.002126, acc_train 0.823250, acc_test 0.812800
# epoch 20, loss_train 0.001992, loss_test 0.002100, acc_train 0.825133, acc_test 0.814300
# epoch 21, loss_train 0.001965, loss_test 0.002078, acc_train 0.827233, acc_test 0.814500
# epoch 22, loss_train 0.001941, loss_test 0.002058, acc_train 0.829150, acc_test 0.816600
# epoch 23, loss_train 0.001920, loss_test 0.002043, acc_train 0.830617, acc_test 0.818400
# epoch 24, loss_train 0.001900, loss_test 0.002022, acc_train 0.831450, acc_test 0.819900
# epoch 25, loss_train 0.001884, loss_test 0.002006, acc_train 0.833350, acc_test 0.821100
# epoch 26, loss_train 0.001867, loss_test 0.001994, acc_train 0.834283, acc_test 0.821300
# epoch 27, loss_train 0.001850, loss_test 0.001980, acc_train 0.836250, acc_test 0.822700
# epoch 28, loss_train 0.001835, loss_test 0.001964, acc_train 0.837067, acc_test 0.825200
# epoch 29, loss_train 0.001822, loss_test 0.001953, acc_train 0.837700, acc_test 0.824700
# epoch 30, loss_train 0.001808, loss_test 0.001944, acc_train 0.839417, acc_test 0.826400

# %%
plt.figure(figsize=(10,7))
plt.plot(loss_train_relu,label='relu',color='blue')
plt.plot(loss_train_leakyrelu,label='leakyrelu', color='orange', linestyle='--')
plt.plot(loss_train_tanh,label='tanh', color='red')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.title("Train Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.plot(loss_test_relu,label='relu',color='blue')
plt.plot(loss_test_leakyrelu,label='leakyrelu', color='orange', linestyle='--')
plt.plot(loss_test_tanh,label='tanh', color='red')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.title("Test Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.plot(acc_train_relu,label='relu',color='blue')
plt.plot(acc_train_leakyrelu,label='leakyrelu', color='orange')
plt.plot(acc_train_tanh,label='tanh', color='red', linestyle='--')
plt.ylabel("acc")
plt.xlabel("epoch")
plt.title("Train Acc")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.plot(acc_test_relu,label='relu',color='blue')
plt.plot(acc_test_leakyrelu,label='leakyrelu', color='orange')
plt.plot(acc_test_tanh,label='tanh', color='red', linestyle='--')
plt.ylabel("acc")
plt.xlabel("epoch")
plt.title("Test Acc")
plt.legend()
plt.show()
