# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn

# %%
# 处理客车数据，总共218张，前153张为训练集，后65张为测试集

# =================== 训练集 =================== #
path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\bus\\bus001.jpg"
train_features = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
for i in range(2,10):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\bus\\bus00"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    train_features = torch.cat((train_features,img), dim=0)
for i in range(10,100):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\bus\\bus0"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    train_features = torch.cat((train_features,img), dim=0)
for i in range(100,101):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\bus\\bus"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    train_features = torch.cat((train_features,img), dim=0)

# =================== 测试集 =================== #
path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\bus\\bus101.jpg"
test_features = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)

for i in range(102,121):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\bus\\bus"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    test_features = torch.cat((test_features,img), dim=0)


# 处理汽车数据，总共779张，前545张为训练集，后234张为测试集

# =================== 训练集 =================== #
for i in range(1,10):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\car\\car00"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    train_features = torch.cat((train_features,img), dim=0)
for i in range(10,100):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\car\\car0"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    train_features = torch.cat((train_features,img), dim=0)
for i in range(100,101):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\car\\car"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    train_features = torch.cat((train_features,img), dim=0)

# =================== 测试集 =================== #
for i in range(101,121):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\car\\car"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    test_features = torch.cat((test_features,img), dim=0)

# 处理货车数据，总共360张，前252张为训练集，后108张为测试集

# =================== 训练集 =================== #
for i in range(1,10):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\truck\\truck00"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    train_features = torch.cat((train_features,img), dim=0)
for i in range(10,100):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\truck\\truck0"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    train_features = torch.cat((train_features,img), dim=0)
for i in range(100,101):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\truck\\truck"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    train_features = torch.cat((train_features,img), dim=0)

# =================== 测试集 =================== #
for i in range(101,121):
    path = "D:\课件-研究生\深度学习_万怀宇\实验3\车辆分类数据集\\truck\\truck"+ str(i) + ".jpg"
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    test_features = torch.cat((test_features,img), dim=0)

train_features = train_features.permute(0,3,2,1)
test_features = test_features.permute(0,3,2,1)
print(train_features.shape)
print(test_features.shape)

# =================== 训练集标签 =================== #
train_labels = torch.zeros(100).long()
train_labels = torch.cat((train_labels,torch.ones(100).long()), dim=0)
train_labels = torch.cat((train_labels,torch.ones(100).long()+1), dim=0)
print(train_labels.shape)

# =================== 测试集标签 =================== #
test_labels = torch.zeros(20).long()
test_labels = torch.cat((test_labels,torch.ones(20).long()), dim=0)
test_labels = torch.cat((test_labels,torch.ones(20).long()+1), dim=0)
print(test_labels.shape)
# Out:
# torch.Size([300, 3, 100, 100])
# torch.Size([60, 3, 100, 100])
# torch.Size([300])
# torch.Size([60])

# %%
# ========================= 定义模型 ========================= #

# ==================== 卷积核大小为3 ==================== #
class ConvModule_3 (torch.nn.Module):
    def __init__(self):
        super(ConvModule_3, self).__init__()
        #定义一个一层卷积
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)           
        )
        self.fc = nn.Linear(32, num_classes) #[32,3] ,32是卷积输出的通道数，out_channels是多少这里就是多少
 
    def forward(self, X):
        #X = X.requires_grad_()
        out = self.conv(X)
        #print(out.shape)  #torch.Size([32, 32, 98, 98])
        out = nn.functional.avg_pool2d(out, 98)
        #print(out.shape) #torch.Size([32, 32, 1, 1])
        out = out.squeeze()
        #print(out.shape) #torch.Size([32, 32])
        out = self.fc(out)
        return out
    
# ==================== 卷积核大小为5 ==================== #
class ConvModule_5 (torch.nn.Module):
    def __init__(self):
        super(ConvModule_5, self).__init__()
        #定义一个一层卷积
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, stride=1, padding=0),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)           
        )
        self.fc = nn.Linear(32, num_classes) #[32,3] ,32是卷积输出的通道数，out_channels是多少这里就是多少
 
    def forward(self, X):
        #X = X.requires_grad_()
        out = self.conv(X)
        #print(out.shape)  #torch.Size([32, 32, 96, 96])
        out = nn.functional.avg_pool2d(out, 96)
        #print(out.shape) #torch.Size([32, 32, 1, 1])
        out = out.squeeze()
        #print(out.shape) #torch.Size([32, 32])
        out = self.fc(out)
        return out
    
# ==================== 卷积核大小为7 ==================== #
class ConvModule_7 (torch.nn.Module):
    def __init__(self):
        super(ConvModule_7, self).__init__()
        #定义一个一层卷积
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7, stride=1, padding=0),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)           
        )
        self.fc = nn.Linear(32, num_classes) #[32,3] ,32是卷积输出的通道数，out_channels是多少这里就是多少
 
    def forward(self, X):
        #X = X.requires_grad_()
        out = self.conv(X)
        #print(out.shape)  #torch.Size([32, 32, 94, 94])
        out = nn.functional.avg_pool2d(out, 94)
        #print(out.shape) #torch.Size([32, 32, 1, 1])
        out = out.squeeze()
        #print(out.shape) #torch.Size([32, 32])
        out = self.fc(out)
        return out

# %%
#训练函数
def train_epoch(net, data_loader):
    
    net.train()
    train_batch_num = len(data_loader)
    total_loss = 0
    correct = 0
    sample_num = 0
    
    for batch_idx, (data, target) in enumerate(data_loader):
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        prediction = torch.argmax(output, 1)
        correct += (prediction == target).sum().item()
        sample_num += len(prediction)
    
    loss = total_loss / train_batch_num
    acc = correct / sample_num
    return loss, acc

#测试函数
def test_epoch(net, data_loader):
    
    net.eval()
    test_batch_num = len(data_loader)
    total_loss = 0
    correct = 0
    sample_num = 0
    
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(data_loader):
            output = net(data)
            loss = criterion(output, target)
            total_loss += loss.item()
            prediction = torch.argmax(output, 1)
            correct += (prediction == target).sum().item()
            sample_num += len(prediction)
    
    loss = total_loss / test_batch_num
    acc = correct / sample_num
    return loss, acc

num_classes = 3
num_epoch = 50
lr = 0.001
batch_size = 32

#划分数据集
train_dataset = torch.utils.data.TensorDataset(train_features,train_labels)
train_iter = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, num_workers=0)
test_dataset = torch.utils.data.TensorDataset(test_features,test_labels)
test_iter = torch.utils.data.DataLoader(test_dataset, batch_size, shuffle=True, num_workers=0)

# %%
# ==================== 卷积核大小为3 ==================== #

net = ConvModule_3()
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=lr)

train_loss_3 = []
train_acc_3 = []
test_loss_3 = []
test_acc_3 = []

for epoch in range(num_epoch):
    
    train_loss, train_acc = train_epoch(net, data_loader=train_iter)
    test_loss, test_acc = test_epoch(net, data_loader=test_iter)
    
    train_loss_3.append(train_loss)
    train_acc_3.append(train_acc)
    test_loss_3.append(test_loss)
    test_acc_3.append(test_acc)
    
    print('epoch %d, train_loss %f, test_loss %f, train_acc %f, test_acc %f' % 
          (epoch+1, train_loss, test_loss, train_acc, test_acc))
# Out:
# epoch 1, train_loss 1.106994, test_loss 1.084031, train_acc 0.333333, test_acc 0.333333
# epoch 2, train_loss 1.005498, test_loss 1.054545, train_acc 0.390000, test_acc 0.333333
# epoch 3, train_loss 0.934508, test_loss 1.012514, train_acc 0.593333, test_acc 0.566667
# epoch 4, train_loss 0.892070, test_loss 0.962180, train_acc 0.643333, test_acc 0.533333
# epoch 5, train_loss 0.857165, test_loss 0.909799, train_acc 0.666667, test_acc 0.533333
# epoch 28, train_loss 0.718299, test_loss 0.772628, train_acc 0.653333, test_acc 0.600000
# epoch 29, train_loss 0.688942, test_loss 0.920169, train_acc 0.706667, test_acc 0.466667
# epoch 30, train_loss 0.692596, test_loss 0.800379, train_acc 0.690000, test_acc 0.600000
# epoch 31, train_loss 0.685168, test_loss 0.735652, train_acc 0.680000, test_acc 0.650000
# epoch 32, train_loss 0.705588, test_loss 0.685199, train_acc 0.686667, test_acc 0.783333
# epoch 33, train_loss 0.702448, test_loss 0.805210, train_acc 0.696667, test_acc 0.600000
# epoch 34, train_loss 0.677296, test_loss 0.734524, train_acc 0.686667, test_acc 0.616667
# epoch 35, train_loss 0.705691, test_loss 0.825406, train_acc 0.693333, test_acc 0.550000
# epoch 36, train_loss 0.679240, test_loss 0.807470, train_acc 0.716667, test_acc 0.583333
# epoch 37, train_loss 0.671676, test_loss 0.841015, train_acc 0.696667, test_acc 0.583333
# epoch 38, train_loss 0.664287, test_loss 0.714124, train_acc 0.696667, test_acc 0.666667
# epoch 39, train_loss 0.660677, test_loss 1.109960, train_acc 0.693333, test_acc 0.500000
# epoch 40, train_loss 0.645586, test_loss 0.685682, train_acc 0.703333, test_acc 0.750000
# epoch 41, train_loss 0.669479, test_loss 0.680205, train_acc 0.716667, test_acc 0.833333
# epoch 42, train_loss 0.642162, test_loss 0.679373, train_acc 0.693333, test_acc 0.833333
# epoch 43, train_loss 0.657264, test_loss 0.821462, train_acc 0.690000, test_acc 0.566667
# epoch 44, train_loss 0.656051, test_loss 0.859511, train_acc 0.696667, test_acc 0.566667
# epoch 45, train_loss 0.704908, test_loss 0.769660, train_acc 0.683333, test_acc 0.616667
# epoch 46, train_loss 0.671244, test_loss 0.723186, train_acc 0.716667, test_acc 0.733333
# epoch 47, train_loss 0.657595, test_loss 0.761544, train_acc 0.703333, test_acc 0.633333
# epoch 48, train_loss 0.670775, test_loss 0.996362, train_acc 0.693333, test_acc 0.500000
# epoch 49, train_loss 0.659465, test_loss 0.648454, train_acc 0.703333, test_acc 0.833333
# epoch 50, train_loss 0.661230, test_loss 0.755223, train_acc 0.720000, test_acc 0.583333

# %%
plt.plot(train_loss_3,label='kernel_size=3',color='blue')
plt.plot(train_loss_5,label='kernel_size=5', color='orange')
plt.plot(train_loss_7,label='kernel_size=7', color='red')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.title("Train Loss")
plt.legend()
plt.show()

# %%
plt.plot(test_loss_3,label='kernel_size=3',color='blue')
plt.plot(test_loss_5,label='kernel_size=5', color='orange')
plt.plot(test_loss_7,label='kernel_size=7', color='red')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.title("Test Loss")
plt.legend()
plt.show()

# %%
plt.plot(train_acc_3,label='kernel_size=3',color='blue')
plt.plot(train_acc_5,label='kernel_size=5', color='orange')
plt.plot(train_acc_7,label='kernel_size=7', color='red')
plt.ylabel("acc")
plt.xlabel("epoch")
plt.title("Train Acc")
plt.legend()
plt.show()

# %%
plt.plot(test_acc_3,label='kernel_size=3',color='blue')
plt.plot(test_acc_5,label='kernel_size=5', color='orange')
plt.plot(test_acc_7,label='kernel_size=7', color='red')
plt.ylabel("acc")
plt.xlabel("epoch")
plt.title("Test Acc")
plt.legend()
plt.show()
