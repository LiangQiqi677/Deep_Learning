# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import os
import datetime

device = torch.device("cuda:0")

path = "./车辆分类数据集/bus/bus001.jpg"
train_features = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
test_features = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)

# 处理客车数据，总共218张，前153张为训练集，后65张为测试集
pic_num = 0
for filename in os.listdir("./车辆分类数据集/bus/"): 
    pic_num = pic_num + 1
    path = "./车辆分类数据集/bus/"+ filename
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    if pic_num <= 153:
        train_features = torch.cat((train_features,img), dim=0)
    else:
        test_features = torch.cat((test_features,img), dim=0)

# 处理汽车数据，总共779张，前545张为训练集，后234张为测试集
pic_num = 0
for filename in os.listdir("./车辆分类数据集/car/"): 
    pic_num = pic_num + 1
    path = "./车辆分类数据集/car/"+ filename
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    if pic_num <= 545:
        train_features = torch.cat((train_features,img), dim=0)
    else:
        test_features = torch.cat((test_features,img), dim=0)

# 处理货车数据，总共360张，前252张为训练集，后108张为测试集
pic_num = 0
for filename in os.listdir("./车辆分类数据集/truck/"): 
    pic_num = pic_num + 1
    path = "./车辆分类数据集/truck/"+ filename
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    if pic_num <= 252:
        train_features = torch.cat((train_features,img), dim=0)
    else:
        test_features = torch.cat((test_features,img), dim=0)

train_features = train_features.permute(0,3,2,1)
test_features = test_features.permute(0,3,2,1)
print(train_features.shape)
print(test_features.shape)

# =================== 训练集标签 =================== #
train_labels = torch.zeros(154).long()
train_labels = torch.cat((train_labels,torch.ones(545).long()), dim=0)
train_labels = torch.cat((train_labels,torch.ones(252).long()+1), dim=0)
print(train_labels.shape)

# =================== 测试集标签 =================== #
test_labels = torch.zeros(66).long()
test_labels = torch.cat((test_labels,torch.ones(234).long()), dim=0)
test_labels = torch.cat((test_labels,torch.ones(108).long()+1), dim=0)
print(test_labels.shape)
# Out:
# torch.Size([951, 3, 100, 100])
# torch.Size([408, 3, 100, 100])
# torch.Size([951])
# torch.Size([408])

# %%
# ========================= 定义模型 ========================= #

# ==================== 卷积层数为1 ==================== #
class ConvModule_1 (torch.nn.Module):
    def __init__(self):
        super(ConvModule_1, self).__init__()
        #定义一个一层卷积
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)           
        )
        self.fc = nn.Linear(32, num_classes) #[32,3] ,32是卷积输出的通道数，out_channels是多少这里就是多少
 
    def forward(self, X):
        #X = X.requires_grad_()
        out = self.conv(X)
        #print(out.shape)  #torch.Size([32, 32, 98, 98])
        out = nn.functional.avg_pool2d(out, 98)
        #print(out.shape) #torch.Size([32, 32, 1, 1])
        out = out.squeeze()
        #print(out.shape) #torch.Size([32, 32])
        out = self.fc(out)
        return out
    
# ==================== 卷积层数为2 ==================== #
class ConvModule_2 (torch.nn.Module):
    def __init__(self):
        super(ConvModule_2, self).__init__()
        #定义一个二层卷积
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        self.fc = nn.Linear(64, num_classes) #[32,3] ,32是卷积输出的通道数，out_channels是多少这里就是多少
 
    def forward(self, X):
        #X = X.requires_grad_()
        out = self.conv(X)
        #print(out.shape)  #torch.Size([32, 32, 96, 96])
        out = nn.functional.avg_pool2d(out, 96)
        #print(out.shape) #torch.Size([32, 32, 1, 1])
        out = out.squeeze()
        #print(out.shape) #torch.Size([32, 32])
        out = self.fc(out)
        return out
    
# ==================== 卷积层数为3 ==================== #
class ConvModule_3 (torch.nn.Module):
    def __init__(self):
        super(ConvModule_3, self).__init__()
        #定义一个三层卷积
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True), 
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True) 
        )
        self.fc = nn.Linear(128, num_classes) #[32,3] ,32是卷积输出的通道数，out_channels是多少这里就是多少
 
    def forward(self, X):
        #X = X.requires_grad_()
        out = self.conv(X)
        #print(out.shape)  #torch.Size([32, 32, 94, 94])
        out = nn.functional.avg_pool2d(out, 94)
        #print(out.shape) #torch.Size([32, 32, 1, 1])
        out = out.squeeze()
        #print(out.shape) #torch.Size([32, 32])
        out = self.fc(out)
        return out

# %%
#训练函数
def train_epoch(net, data_loader, device):
    
    net.train()
    train_batch_num = len(data_loader)
    total_loss = 0
    correct = 0
    sample_num = 0
    
    for batch_idx, (data, target) in enumerate(data_loader):
        data = data.to(device).float()
        target = target.to(device).long()
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        prediction = torch.argmax(output, 1)
        correct += (prediction == target).sum().item()
        sample_num += len(prediction)
    
    loss = total_loss / train_batch_num
    acc = correct / sample_num
    return loss, acc

#测试函数
def test_epoch(net, data_loader, device):
    
    net.eval()
    test_batch_num = len(data_loader)
    total_loss = 0
    correct = 0
    sample_num = 0
    
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(data_loader):
            data = data.to(device).float()
            target = target.to(device).long()
            output = net(data)
            loss = criterion(output, target)
            total_loss += loss.item()
            prediction = torch.argmax(output, 1)
            correct += (prediction == target).sum().item()
            sample_num += len(prediction)
    
    loss = total_loss / test_batch_num
    acc = correct / sample_num
    return loss, acc

num_classes = 3
num_epoch = 100
lr = 0.001
batch_size = 128

#划分数据集
train_dataset = torch.utils.data.TensorDataset(train_features,train_labels)
train_iter = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, num_workers=0)
test_dataset = torch.utils.data.TensorDataset(test_features,test_labels)
test_iter = torch.utils.data.DataLoader(test_dataset, batch_size, shuffle=True, num_workers=0)

# %%
# ==================== 卷积层数为1 ==================== #

net = ConvModule_1().to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=lr)

train_loss_3 = []
train_acc_3 = []
test_loss_3 = []
test_acc_3 = []

start1 = datetime.datetime.now()
for epoch in range(num_epoch):
    
    train_loss, train_acc = train_epoch(net, train_iter, device)
    test_loss, test_acc = test_epoch(net, test_iter, device)
    
    train_loss_3.append(train_loss)
    train_acc_3.append(train_acc)
    test_loss_3.append(test_loss)
    test_acc_3.append(test_acc)
    
    print('epoch %d, train_loss %f, test_loss %f, train_acc %f, test_acc %f' % 
          (epoch+1, train_loss, test_loss, train_acc, test_acc))
end1 = datetime.datetime.now()
print("一层卷积执行时间：")
print(end1 - start1)
# Out:
# epoch 1, train_loss 1.142038, test_loss 1.047495, train_acc 0.291272, test_acc 0.573529
# epoch 2, train_loss 1.051102, test_loss 1.023312, train_acc 0.529968, test_acc 0.573529
# epoch 3, train_loss 0.982209, test_loss 1.024629, train_acc 0.581493, test_acc 0.573529
# epoch 4, train_loss 0.944884, test_loss 0.972872, train_acc 0.582545, test_acc 0.573529
# epoch 5, train_loss 0.909205, test_loss 0.917741, train_acc 0.582545, test_acc 0.573529
# epoch 6, train_loss 0.886656, test_loss 0.947631, train_acc 0.585699, test_acc 0.573529
# epoch 7, train_loss 0.865981, test_loss 0.845231, train_acc 0.590957, test_acc 0.568627
# epoch 8, train_loss 0.847197, test_loss 0.845690, train_acc 0.592008, test_acc 0.568627
# epoch 9, train_loss 0.833385, test_loss 0.881550, train_acc 0.593060, test_acc 0.590686
# epoch 10, train_loss 0.823141, test_loss 0.866110, train_acc 0.603575, test_acc 0.593137
# epoch 11, train_loss 0.821829, test_loss 0.831045, train_acc 0.608833, test_acc 0.620098
# epoch 12, train_loss 0.809319, test_loss 0.799280, train_acc 0.617245, test_acc 0.644608
# epoch 13, train_loss 0.800006, test_loss 0.806184, train_acc 0.631966, test_acc 0.637255
# epoch 14, train_loss 0.799220, test_loss 0.806922, train_acc 0.649842, test_acc 0.622549
# epoch 15, train_loss 0.788665, test_loss 0.794017, train_acc 0.650894, test_acc 0.710784
# epoch 79, train_loss 0.603396, test_loss 0.584996, train_acc 0.834911, test_acc 0.811275
# epoch 80, train_loss 0.591035, test_loss 0.664651, train_acc 0.824395, test_acc 0.811275
# epoch 81, train_loss 0.593695, test_loss 0.640568, train_acc 0.827550, test_acc 0.776961
# epoch 82, train_loss 0.581408, test_loss 0.684508, train_acc 0.818086, test_acc 0.735294
# epoch 83, train_loss 0.579153, test_loss 0.627971, train_acc 0.821241, test_acc 0.806373
# epoch 84, train_loss 0.587638, test_loss 0.616979, train_acc 0.824395, test_acc 0.786765
# epoch 85, train_loss 0.596585, test_loss 0.632204, train_acc 0.827550, test_acc 0.806373
# epoch 86, train_loss 0.580084, test_loss 0.658789, train_acc 0.833859, test_acc 0.745098
# epoch 87, train_loss 0.592801, test_loss 0.598246, train_acc 0.822292, test_acc 0.835784
# epoch 88, train_loss 0.591847, test_loss 1.019098, train_acc 0.830705, test_acc 0.531863
# epoch 89, train_loss 0.580676, test_loss 0.657748, train_acc 0.813880, test_acc 0.757353
# epoch 90, train_loss 0.587187, test_loss 0.806539, train_acc 0.811777, test_acc 0.678922
# epoch 91, train_loss 0.578463, test_loss 0.607027, train_acc 0.834911, test_acc 0.828431
# epoch 92, train_loss 0.568884, test_loss 0.569814, train_acc 0.829653, test_acc 0.833333
# epoch 93, train_loss 0.562814, test_loss 0.625331, train_acc 0.837014, test_acc 0.769608
# epoch 94, train_loss 0.567538, test_loss 0.568609, train_acc 0.831756, test_acc 0.825980
# epoch 95, train_loss 0.562810, test_loss 0.548659, train_acc 0.832808, test_acc 0.803922
# epoch 96, train_loss 0.562285, test_loss 0.572702, train_acc 0.842271, test_acc 0.838235
# epoch 97, train_loss 0.556309, test_loss 0.620690, train_acc 0.837014, test_acc 0.796569
# epoch 98, train_loss 0.543882, test_loss 0.632171, train_acc 0.830705, test_acc 0.774510
# epoch 99, train_loss 0.555858, test_loss 0.715319, train_acc 0.839117, test_acc 0.713235
# epoch 100, train_loss 0.565956, test_loss 0.614383, train_acc 0.822292, test_acc 0.821078
# 一层卷积执行时间：
# 0:00:28.626646

# %%
# ==================== 卷积层数为2 ==================== #

net = ConvModule_2().to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=lr)

train_loss_5 = []
train_acc_5 = []
test_loss_5 = []
test_acc_5 = []

start2 = datetime.datetime.now()
for epoch in range(num_epoch):
    
    train_loss, train_acc = train_epoch(net, train_iter, device)
    test_loss, test_acc = test_epoch(net, test_iter, device)
    
    train_loss_5.append(train_loss)
    train_acc_5.append(train_acc)
    test_loss_5.append(test_loss)
    test_acc_5.append(test_acc)
    
    print('epoch %d, train_loss %f, test_loss %f, train_acc %f, test_acc %f' % 
          (epoch+1, train_loss, test_loss, train_acc, test_acc))
end2 = datetime.datetime.now()
print("两层卷积执行时间：")
print(end2 - start2)
# Out:
# epoch 1, train_loss 0.924036, test_loss 0.996371, train_acc 0.672976, test_acc 0.573529
# epoch 82, train_loss 0.159332, test_loss 0.413140, train_acc 0.930599, test_acc 0.828431
# epoch 83, train_loss 0.186218, test_loss 0.317042, train_acc 0.932702, test_acc 0.872549
# epoch 84, train_loss 0.185543, test_loss 0.774169, train_acc 0.935857, test_acc 0.843137
# epoch 85, train_loss 0.179040, test_loss 0.406250, train_acc 0.930599, test_acc 0.860294
# epoch 86, train_loss 0.159562, test_loss 0.559503, train_acc 0.937960, test_acc 0.757353
# epoch 87, train_loss 0.152649, test_loss 0.336941, train_acc 0.946372, test_acc 0.887255
# epoch 88, train_loss 0.145105, test_loss 0.463063, train_acc 0.953733, test_acc 0.848039
# epoch 89, train_loss 0.158767, test_loss 0.941324, train_acc 0.949527, test_acc 0.781863
# epoch 90, train_loss 0.173633, test_loss 0.667396, train_acc 0.931651, test_acc 0.715686
# epoch 91, train_loss 0.156126, test_loss 0.419473, train_acc 0.955836, test_acc 0.879902
# epoch 92, train_loss 0.141075, test_loss 0.341361, train_acc 0.945321, test_acc 0.872549
# epoch 93, train_loss 0.146330, test_loss 0.207886, train_acc 0.952681, test_acc 0.914216
# epoch 94, train_loss 0.146040, test_loss 1.125906, train_acc 0.947424, test_acc 0.610294
# epoch 95, train_loss 0.135316, test_loss 0.473943, train_acc 0.947424, test_acc 0.813725
# epoch 96, train_loss 0.128689, test_loss 0.224093, train_acc 0.965300, test_acc 0.921569
# epoch 97, train_loss 0.134611, test_loss 0.373001, train_acc 0.953733, test_acc 0.879902
# epoch 98, train_loss 0.144755, test_loss 0.300336, train_acc 0.942166, test_acc 0.892157
# epoch 99, train_loss 0.156803, test_loss 0.766307, train_acc 0.946372, test_acc 0.767157
# epoch 100, train_loss 0.156741, test_loss 1.258062, train_acc 0.950578, test_acc 0.671569
# 三层卷积执行时间：
# 0:02:00.768986

# %%
plt.plot(train_loss_3,label='Conv_layer=1',color='blue')
plt.plot(train_loss_5,label='Conv_layer=2', color='orange')
plt.plot(train_loss_7,label='Conv_layer=3', color='red')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.title("Train Loss")
plt.legend()
plt.show()

# %%
plt.plot(test_loss_3,label='Conv_layer=1',color='blue')
plt.plot(test_loss_5,label='Conv_layer=2', color='orange')
plt.plot(test_loss_7,label='Conv_layer=3', color='red')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.title("Test Loss")
plt.legend()
plt.show()

# %%
plt.plot(train_acc_3,label='Conv_layer=1',color='blue')
plt.plot(train_acc_5,label='Conv_layer=2', color='orange')
plt.plot(train_acc_7,label='Conv_layer=3', color='red')
plt.ylabel("acc")
plt.xlabel("epoch")
plt.title("Train Acc")
plt.legend()
plt.show()

# %%
plt.plot(test_acc_3,label='Conv_layer=1',color='blue')
plt.plot(test_acc_5,label='Conv_layer=2', color='orange')
plt.plot(test_acc_7,label='Conv_layer=3', color='red')
plt.ylabel("acc")
plt.xlabel("epoch")
plt.title("Test Acc")
plt.legend()
plt.show()
