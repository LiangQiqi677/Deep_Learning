# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import os
import datetime

device = torch.device("cuda:0")

path = "./车辆分类数据集/bus/bus001.jpg"
train_features = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
test_features = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)

# 处理客车数据，总共218张，前153张为训练集，后65张为测试集
pic_num = 0
for filename in os.listdir("./车辆分类数据集/bus/"): 
    pic_num = pic_num + 1
    path = "./车辆分类数据集/bus/"+ filename
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    if pic_num <= 153:
        train_features = torch.cat((train_features,img), dim=0)
    else:
        test_features = torch.cat((test_features,img), dim=0)

# 处理汽车数据，总共779张，前545张为训练集，后234张为测试集
pic_num = 0
for filename in os.listdir("./车辆分类数据集/car/"): 
    pic_num = pic_num + 1
    path = "./车辆分类数据集/car/"+ filename
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    if pic_num <= 545:
        train_features = torch.cat((train_features,img), dim=0)
    else:
        test_features = torch.cat((test_features,img), dim=0)

# 处理货车数据，总共360张，前252张为训练集，后108张为测试集
pic_num = 0
for filename in os.listdir("./车辆分类数据集/truck/"): 
    pic_num = pic_num + 1
    path = "./车辆分类数据集/truck/"+ filename
    img = torch.Tensor(np.array(Image.open(path).resize((100,100),Image.ANTIALIAS))/255).view(1, 100, 100, 3)
    if pic_num <= 252:
        train_features = torch.cat((train_features,img), dim=0)
    else:
        test_features = torch.cat((test_features,img), dim=0)

train_features = train_features.permute(0,3,2,1)
test_features = test_features.permute(0,3,2,1)
print(train_features.shape)
print(test_features.shape)

# =================== 训练集标签 =================== #
train_labels = torch.zeros(154).long()
train_labels = torch.cat((train_labels,torch.ones(545).long()), dim=0)
train_labels = torch.cat((train_labels,torch.ones(252).long()+1), dim=0)
print(train_labels.shape)

# =================== 测试集标签 =================== #
test_labels = torch.zeros(66).long()
test_labels = torch.cat((test_labels,torch.ones(234).long()), dim=0)
test_labels = torch.cat((test_labels,torch.ones(108).long()+1), dim=0)
print(test_labels.shape)
# Out:
# torch.Size([951, 3, 100, 100])
# torch.Size([408, 3, 100, 100])
# torch.Size([951])
# torch.Size([408])

# %%
# ==================== 空洞卷积 ==================== #
class DilatedConvModule (torch.nn.Module):
    def __init__(self):
        super(DilatedConvModule, self).__init__()
        #定义一个三层卷积
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=0, dilation=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True), 
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=0, dilation=2),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=0, dilation=5),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True) 
        )
        self.fc = nn.Linear(128, num_classes) #[32,3] ,32是卷积输出的通道数，out_channels是多少这里就是多少
 
    def forward(self, X):
        out = self.conv(X)
        #print(out.shape)  #torch.Size([32, 32, 84, 84])
        out = nn.functional.avg_pool2d(out, 84)
        #print(out.shape) #torch.Size([32, 32, 1, 1])
        out = out.squeeze()
        #print(out.shape) #torch.Size([32, 32])
        out = self.fc(out)
        return out

# %%
# ==================== 卷积 ==================== #
class ConvModule (torch.nn.Module):
    def __init__(self):
        super(ConvModule, self).__init__()
        #定义一个三层卷积
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True), 
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=0),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True) 
        )
        self.fc = nn.Linear(128, num_classes) #[32,3] ,32是卷积输出的通道数，out_channels是多少这里就是多少
 
    def forward(self, X):
        out = self.conv(X)
        #print(out.shape)  #torch.Size([32, 32, 84, 84])
        out = nn.functional.avg_pool2d(out, 84)
        #print(out.shape) #torch.Size([32, 32, 1, 1])
        out = out.squeeze()
        #print(out.shape) #torch.Size([32, 32])
        out = self.fc(out)
        return out

# %%
#训练函数
def train_epoch(net, data_loader, device):
    
    net.train()
    train_batch_num = len(data_loader)
    total_loss = 0
    correct = 0
    sample_num = 0
    
    for batch_idx, (data, target) in enumerate(data_loader):
        data = data.to(device).float()
        target = target.to(device).long()
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        prediction = torch.argmax(output, 1)
        correct += (prediction == target).sum().item()
        sample_num += len(prediction)
    
    loss = total_loss / train_batch_num
    acc = correct / sample_num
    return loss, acc

#测试函数
def test_epoch(net, data_loader, device):
    
    net.eval()
    test_batch_num = len(data_loader)
    total_loss = 0
    correct = 0
    sample_num = 0
    
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(data_loader):
            data = data.to(device).float()
            target = target.to(device).long()
            output = net(data)
            loss = criterion(output, target)
            total_loss += loss.item()
            prediction = torch.argmax(output, 1)
            correct += (prediction == target).sum().item()
            sample_num += len(prediction)
    
    loss = total_loss / test_batch_num
    acc = correct / sample_num
    return loss, acc

num_classes = 3
num_epoch = 100
lr = 0.001
batch_size = 32

#划分数据集
train_dataset = torch.utils.data.TensorDataset(train_features,train_labels)
train_iter = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, num_workers=0)
test_dataset = torch.utils.data.TensorDataset(test_features,test_labels)
test_iter = torch.utils.data.DataLoader(test_dataset, batch_size, shuffle=True, num_workers=0)

# %%
# ==================== 空洞卷积 ==================== #

net = DilatedConvModule().to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam
# epoch 79, train_loss 0.144684, test_loss 1.784499, train_acc 0.949527, test_acc 0.480392
# epoch 80, train_loss 0.126609, test_loss 0.392366, train_acc 0.951630, test_acc 0.848039
# epoch 81, train_loss 0.128012, test_loss 0.333976, train_acc 0.953733, test_acc 0.882353
# epoch 82, train_loss 0.130456, test_loss 0.287734, train_acc 0.947424, test_acc 0.892157
# epoch 83, train_loss 0.134006, test_loss 0.572452, train_acc 0.945321, test_acc 0.764706
# epoch 84, train_loss 0.125291, test_loss 0.260117, train_acc 0.952681, test_acc 0.911765
# epoch 85, train_loss 0.136490, test_loss 0.262599, train_acc 0.951630, test_acc 0.921569
# epoch 86, train_loss 0.118118, test_loss 0.268321, train_acc 0.957939, test_acc 0.926471
# epoch 87, train_loss 0.126912, test_loss 0.309130, train_acc 0.944269, test_acc 0.865196
# epoch 88, train_loss 0.106995, test_loss 0.367928, train_acc 0.964248, test_acc 0.870098
# epoch 89, train_loss 0.116342, test_loss 0.475141, train_acc 0.953733, test_acc 0.791667
# epoch 90, train_loss 0.121320, test_loss 1.068343, train_acc 0.953733, test_acc 0.686275
# epoch 91, train_loss 0.126326, test_loss 0.561292, train_acc 0.953733, test_acc 0.843137
# epoch 92, train_loss 0.110554, test_loss 0.283550, train_acc 0.951630, test_acc 0.914216
# epoch 93, train_loss 0.101369, test_loss 0.727305, train_acc 0.964248, test_acc 0.840686
# epoch 94, train_loss 0.114396, test_loss 0.330118, train_acc 0.962145, test_acc 0.906863
# epoch 95, train_loss 0.112564, test_loss 0.670476, train_acc 0.961094, test_acc 0.806373
# epoch 96, train_loss 0.120228, test_loss 1.487010, train_acc 0.960042, test_acc 0.563725
# epoch 97, train_loss 0.097028, test_loss 0.311226, train_acc 0.966351, test_acc 0.901961
# epoch 98, train_loss 0.109425, test_loss 0.261666, train_acc 0.960042, test_acc 0.931373
# epoch 99, train_loss 0.119574, test_loss 0.760317, train_acc 0.953733, test_acc 0.769608
# epoch 100, train_loss 0.133755, test_loss 0.427044, train_acc 0.948475, test_acc 0.892157
# 卷积执行时间：
# 0:02:04.709229

# %%
plt.plot(train_loss_d ,label='DilatedConv',color='blue')
plt.plot(train_loss_c ,label='Conv', color='orange')
plt.ylabel("train_loss")
plt.xlabel("epoch")
plt.title("train_loss")
plt.legend()
plt.show()

# %%
plt.plot(test_loss_d ,label='DilatedConv',color='blue')
plt.plot(test_loss_c ,label='Conv', color='orange')
plt.ylabel("test_loss")
plt.xlabel("epoch")
plt.title("test_loss")
plt.legend()
plt.show()

# %%
plt.plot(train_acc_d ,label='DilatedConv',color='blue')
plt.plot(train_acc_c ,label='Conv', color='orange')
plt.ylabel("train_acc")
plt.xlabel("epoch")
plt.title("train_acc")
plt.legend()
plt.show()

# %%
plt.plot(test_acc_d ,label='DilatedConv',color='blue')
plt.plot(test_acc_c ,label='Conv', color='orange')
plt.ylabel("test_acc")
plt.xlabel("epoch")
plt.title("test_acc")
plt.legend()
plt.show()
